# %% [markdown]
# # API testing

# %% [markdown]
# # Choosing which API

# %% [markdown]
# ### Alpha Vantage API

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
def get_alpha_vantage_news(api_key, ticker, topic=None):
    """
    Fetches news articles about `ticker` from the Alpha Vantage News API.
    Optionally filters by `topic` (e.g., "technology", "finance", etc.).
    Returns a list of dicts with article info (title, summary, sentiment, etc.).
    """

    # Alpha Vantage 'NEWS_SENTIMENT' endpoint
    url = "https://www.alphavantage.co/query"

    # Base params
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": ticker,
        "apikey": api_key
    }

    # If a topic was provided, include it in the params
    # NOTE: The Alpha Vantage parameter for filtering by topic is "topics".
    # E.g., topics=technology,ipo
    if topic:
        params["topics"] = topic

    response = requests.get(url, params=params)
    print("Request URL:", response.url)  # Debugging: see the final request
    data = response.json()

    # Check for errors
    if "feed" not in data:
        print(f"Error fetching news from Alpha Vantage: {data}")
        return []

    articles = data["feed"]
    return articles


def main():
    # 1. Prompt user for inputs
    ticker = input("Enter the company ticker symbol (e.g., AAPL, TSLA): ").upper()
    limit_str = input("How many news articles would you like to see? (default 5): ")
    
    print("\nAvailable topics include:")
    print("  blockchain, earnings, ipo, mergers_and_acquisitions, financial_markets,")
    print("  economy_fiscal, economy_monetary, economy_macro, energy_transportation,")
    print("  finance, life_sciences, manufacturing, real_estate, retail_wholesale, technology\n")
    
    topic_input = input("Enter a topic from the list above (or leave blank for none): ").strip()

    # Convert limit input to int
    try:
        limit = int(limit_str)
    except ValueError:
        # If user input is empty or invalid, default to 5
        limit = 5

    # 2. Your Alpha Vantage API key (replace with your actual key)
    ALPHA_VANTAGE_API_KEY = ""

    # 3. Retrieve news articles (potentially filtered by topic)
    articles = get_alpha_vantage_news(ALPHA_VANTAGE_API_KEY, ticker, topic=topic_input)

    # If Alpha Vantage does not respect a 'limit' parameter for news,
    # we apply the limit client-side:
    articles = articles[:limit]

    # 4. Print out the results
    if not articles:
        print("No articles found or there was an error.")
        return

    print(f"\n=== Top {limit} News Articles for {ticker} (Topic: {topic_input or 'None'}) ===")
    for i, article in enumerate(articles, start=1):
        title = article.get("title", "No Title")
        summary = article.get("summary", "No Summary")
        sentiment = article.get("overall_sentiment_label", "No Sentiment")
        url = article.get("url", "No URL")

        print(f"\nArticle {i}:")
        print(f"Title: {title}")
        print(f"Sentiment: {sentiment}")
        print(f"Summary: {summary[:200]}...")  # limit summary preview
        print(f"Link: {url}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Available topics include:
#   blockchain, earnings, ipo, mergers_and_acquisitions, financial_markets,
#   economy_fiscal, economy_monetary, economy_macro, energy_transportation,
#   finance, life_sciences, manufacturing, real_estate, retail_wholesale, technology
#
# Request URL: https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=TSLA&apikey=RAL8AFRU7F2Y9ZPI
#
# === Top 5 News Articles for TSLA (Topic: None) ===
#
# Article 1:
# Title: AI's $19.9 Trillion Impact Could Create The First Trillionaire-But Mark Cuban Says It Won't Be Musk Or Bezos - Alphabet  ( NASDAQ:GOOGL ) , Amazon.com  ( NASDAQ:AMZN )
# Sentiment: Somewhat-Bullish
# Summary: As of this month, Elon Musk, CEO of Tesla TSLA and SpaceX, is still the world's richest person, with a net worth of around $393.2 billion, according to Forbes. While that's an enormous fortune, some e...
# Link: https://www.benzinga.com/news/25/02/43903135/ais-19-9-trillion-impact-could-create-the-first-trillionaire-but-mark-cuban-says-it-wont-be-musk-or-bezos
#
# Article 2:
# Title: Amazon's Jeff Bezos Weighs in on Next James Bond - Fans Agree on a Clear Favorite
# Sentiment: Somewhat-Bullish
# Summary: Bezos' takeover of the James Bond franchise sparks a social media buzz for Henry Cavill as the next 007. Amazon's creative shift in the Bond series raises fan concerns after the controversial adaptati...
# Link: https://www.benzinga.com/general/entertainment/25/02/43903075/amazons-jeff-bezos-weighs-in-on-next-james-bond-fans-agree-on-a-clear-favorite
#
# Article 3:
# Title: Is ChargePoint Stock a Buy Now?
# Sentiment: Neutral
# Summary: The future of electric vehicles ( EVs ) promises environmental benefits and shifts toward sustainable energy. However, a crucial barrier stands in the way: insufficient infrastructure. To support wide...
# Link: https://www.fool.com/investing/2025/02/23/is-chargepoint-stock-a-buy-now/
#
# Article 4:
# Title: Rivian's New Edition, Spacex Delays, Tesla's Decline, And Nikola's Bankruptcy: This Week In Mobility - Nikola  ( NASDAQ:NKLA ) , Rivian Automotive  ( NASDAQ:RIVN )
# Sentiment: Neutral
# Summary: The week has been a rollercoaster ride in the tech and automotive sectors. From Rivian's new limited-edition vehicle to SpaceX's controversial delay, Tesla's sales slump, and Nikola's bankruptcy, ther...
# Link: https://www.benzinga.com/tech/25/02/43902958/rivians-new-edition-spacex-delays-teslas-decline-and-nikolas-bankruptcy-this-week-in-mobility
#
# Article 5:
# Title: Elon Musk Demands Federal Workers Justify Their Jobs - Fbi's Kash Patel Tells Employees Not To Respond - Tesla  ( NASDAQ:TSLA )
# Sentiment: Neutral
# Summary: Elon Musk shakes up federal bureaucracy, requiring email justifications for job roles. Musk's email ultimatum to federal employees raises alarms, prompting warnings from agency leaders. Get real-time ...
# Link: https://www.benzinga.com/news/25/02/43902918/elon-musk-demands-federal-workers-justify-their-jobs-fbis-kash-patel-tells-employees-not-to-respond

# %% [markdown]
# ## FinnHub API

# %%
def get_finnhub_news(api_key, ticker):
    """
    Fetches news articles about `ticker` from the Finnhub 'company-news' endpoint.
    Returns a list of dicts with article info (headline, summary, etc.).
    """

    # Define a date range: e.g., 30 days in the past up to today
    to_date = datetime.now().strftime("%Y-%m-%d")
    from_date = (datetime.now() - timedelta(days=30)).strftime("%Y-%m-%d")

    url = "https://finnhub.io/api/v1/company-news"
    params = {
        "symbol": ticker,
        "from": from_date,
        "to": to_date,
        "token": api_key
    }

    response = requests.get(url, params=params)
    print("Request URL:", response.url)  # Debugging: see the final request
    data = response.json()

    # Finnhub returns a list of articles (or an error message)
    if not isinstance(data, list):
        print(f"Error fetching news from Finnhub: {data}")
        return []

    return data


def main():
    # 1. Prompt user for inputs
    ticker = input("Enter the company ticker symbol (e.g., AAPL, TSLA): ").upper()
    limit_str = input("How many news articles would you like to see? (default 5): ")

    # Convert limit input to int
    try:
        limit = int(limit_str)
    except ValueError:
        limit = 5  # default if user input is invalid

    # 2. Your Finnhub API key (replace with your actual key)
    FINNHUB_API_KEY = ""

    # 3. Retrieve news articles
    articles = get_finnhub_news(FINNHUB_API_KEY, ticker)

    # 4. Apply client-side limit
    articles = articles[:limit]

    # 5. Print out the results
    if not articles:
        print("No articles found or there was an error.")
        return

    print(f"\n=== Top {limit} News Articles for {ticker} (Last 30 Days) ===")
    for i, article in enumerate(articles, start=1):
        title = article.get("headline", "No Title")
        summary = article.get("summary", "No Summary")
        url = article.get("url", "No URL")
        source = article.get("source", "No Source")
        published_timestamp = article.get("datetime", 0)

        # Convert Unix timestamp to human-readable date
        published_date = datetime.utcfromtimestamp(published_timestamp).strftime("%Y-%m-%d %H:%M:%S")

        print(f"\nArticle {i}:")
        print(f"Title: {title}")
        print(f"Source: {source}")
        print(f"Published: {published_date}")
        print(f"Summary: {summary[:200]}...")  # limit summary preview
        print(f"Link: {url}")

if __name__ == "__main__":
    main()
# Out:
# Request URL: https://finnhub.io/api/v1/company-news?symbol=AAPL&from=2025-02-02&to=2025-03-04&token=cuu02a9r01qv6ijkqr0gcuu02a9r01qv6ijkqr10
# Error fetching news from Finnhub: {'error': 'Invalid API key'}
# No articles found or there was an error.

# %% [markdown]
# ## Polgyon.io API

# %%
def get_polygon_news(api_key, ticker, limit=5):
    """
    Fetches up to `limit` news articles about `ticker` from the Polygon.io "reference/news" endpoint.
    Returns a list of articles (each is a dict with title, author, description, etc.).
    """

    url = "https://api.polygon.io/v2/reference/news"
    params = {
        "ticker": ticker,
        "limit": limit,
        "apiKey": api_key
    }

    response = requests.get(url, params=params)
    print("Request URL:", response.url)  # For debugging, see the final request

    data = response.json()

    # Polygon.io returns articles under the "results" key
    # Example response structure:
    # {
    #   "status": "OK",
    #   "count": 5,
    #   "results": [
    #       { "title": "...", "article_url": "...", ... },
    #       ...
    #   ]
    # }
    if "results" not in data:
        print(f"Error fetching news from Polygon.io: {data}")
        return []

    return data["results"]


def main():
    # 1. Prompt user for inputs
    ticker = input("Enter the company ticker symbol (e.g., AAPL, TSLA): ").upper()
    limit_str = input("How many news articles would you like to see? (default 5): ")

    # 2. Convert limit input to int or default to 5
    try:
        limit = int(limit_str)
    except ValueError:
        limit = 5

    # 3. Your Polygon.io API key
    #    (Replace with your actual API key; do NOT hardcode in production)
    POLYGON_API_KEY = ""

    # 4. Retrieve news articles
    articles = get_polygon_news(POLYGON_API_KEY, ticker, limit=limit)

    # 5. Print out the results
    if not articles:
        print("No articles found or there was an error.")
        return

    print(f"\n=== Top {limit} News Articles for {ticker} ===")
    for i, article in enumerate(articles, start=1):
        title = article.get("title", "No Title")
        article_url = article.get("article_url", "No URL")
        author = article.get("author", "No Author")
        published_utc = article.get("published_utc", "No Date/Time")
        description = article.get("description", "No Description")

        print(f"\nArticle {i}:")
        print(f"Title: {title}")
        print(f"Author: {author}")
        print(f"Published (UTC): {published_utc}")
        print(f"Description: {description[:200]}...")  # Limit summary preview
        print(f"Link: {article_url}")

if __name__ == "__main__":
    main()
# Out:
# Request URL: https://api.polygon.io/v2/reference/news?ticker=AAPL&limit=5&apiKey=ymrniCK302SrpiQ3WIISSIpIUNbTYSYt
#
# === Top 5 News Articles for AAPL ===
#
# Article 1:
# Title: Palantir Extends Losses, Microsoft Slides: What's Driving Markets Monday?
# Author: Erica Kollmann
# Published (UTC): 2025-02-24T17:54:27Z
# Description: The major indices struggled to maintain early momentum on Monday, with Microsoft, Broadcom, Tesla, and Meta Platforms facing pressure, while Apple announced plans for a $500 billion investment in the ...
# Link: https://www.benzinga.com/general/market-summary/25/02/43920295/palantir-extends-losses-microsoft-slides-whats-driving-markets-monday
#
# Article 2:
# Title: Should You Buy Apple Stock Instead of Microsoft Stock?
# Author: Parkev Tatevosian, Cfa
# Published (UTC): 2025-02-24T14:36:11Z
# Description: The article compares Apple and Microsoft as long-term investments, noting that only one can be the better choice. It provides analysis and recommendations from The Motley Fool....
# Link: https://www.fool.com/investing/2025/02/24/should-you-buy-apple-stock-instead-of-microsoft-st/?source=iedfolrf0000001
#
# Article 3:
# Title: The Smartest Vanguard ETF to Buy With $500 Right Now
# Author: Stefon Walters
# Published (UTC): 2025-02-24T10:26:00Z
# Description: The article discusses the Vanguard S&P 500 Value ETF (VOOV) as a complement to the standard S&P 500 or growth-focused portfolios. It highlights the ETF's value-focused approach and more balanced secto...
# Link: https://www.fool.com/investing/2025/02/24/the-smartest-vanguard-etf-to-buy-with-500-right-no/?source=iedfolrf0000001
#
# Article 4:
# Title: Prediction: 2 AI Stocks Will Be Worth More Than Apple Stock by the Year's End in 2025
# Author: The Motley Fool
# Published (UTC): 2025-02-24T08:34:00Z
# Description: Nvidia and Microsoft are predicted to surpass Apple's current market value of $3.6 trillion by the end of 2025, driven by their dominance in the AI market. Nvidia's AI accelerator sales and Microsoft'...
# Link: https://www.fool.com/investing/2025/02/24/2-ai-stocks-worth-more-than-apple-stock-in-2025/?source=iedfolrf0000001
#
# Article 5:
# Title: Is Warren Buffett Really Fleeing Stocks? These 18 Words From the Billionaire Offer a Strikingly Clear Answer.
# Author: The Motley Fool
# Published (UTC): 2025-02-23T23:10:00Z
# Description: Warren Buffett has been a net seller of stocks, but his recent comments suggest he is not fleeing the stock market. Instead, he may be cautious about high valuations and selectively buying quality sto...
# Link: https://www.fool.com/investing/2025/02/23/is-warren-buffett-really-fleeing-stocks-these-18-w/?source=iedfolrf0000001

# %% [markdown]
# ## Marketaux API

# %%
def get_marketaux_news(api_token, symbols, limit=5):
    """
    Fetches up to `limit` news articles for the given `symbols` from the Marketaux 'v1/news/all' endpoint.
    `symbols` can be a single ticker like 'AAPL' or multiple tickers like 'TSLA,AMZN,MSFT'.
    
    Returns a list of article objects (dicts) with fields such as 'title', 'description', 'source', etc.
    """

    base_url = "https://api.marketaux.com/v1/news/all"
    
    # Build query parameters. We'll include `filter_entities` and `language` as shown in the example.
    # You can adjust or remove them as needed.
    params = {
        "symbols": symbols,           # e.g. "TSLA,AMZN,MSFT" or "AAPL"
        "filter_entities": "true",    # whether to extract entities from the text
        "language": "en",            # language filter for articles
        "api_token": api_token
        # Note: The Marketaux example doesn't show a built-in 'limit' param,
        # so we'll apply the limit client-side below.
    }

    response = requests.get(base_url, params=params)
    print("Request URL:", response.url)  # Debugging: see the final request
    data = response.json()

    # Marketaux's response typically has a structure like:
    # {
    #   "data": [ ... list of articles ... ],
    #   "meta": { ... pagination info ... }
    # }
    # Check if "data" exists in the response
    if "data" not in data:
        print(f"Error fetching news from Marketaux: {data}")
        return []

    articles = data["data"]
    
    # Since Marketaux doesn't necessarily limit results on the server side by default,
    # apply the limit client-side here
    return articles[:limit]


def main():
    # Prompt user for inputs
    symbols = input("Enter one or more comma-separated tickers (e.g., AAPL or TSLA,AMZN,MSFT): ").upper()
    limit_str = input("How many news articles would you like to see? (default 5): ")

    # Convert limit input to int or default to 5
    try:
        limit = int(limit_str)
    except ValueError:
        limit = 5

    # Replace with your actual Marketaux API key
    MARKETAUX_API_TOKEN = ""

    # Fetch the news articles
    articles = get_marketaux_news(MARKETAUX_API_TOKEN, symbols, limit=limit)

    if not articles:
        print("No articles found or there was an error.")
        return

    print(f"\n=== Top {limit} News Articles for {symbols} ===")
    for i, article in enumerate(articles, start=1):
        title = article.get("title", "No Title")
        description = article.get("description", "No Description")
        source = article.get("source", "No Source")
        published_at = article.get("published_at", "No Publish Time")
        url = article.get("url", "No URL")

        print(f"\nArticle {i}:")
        print(f"Title: {title}")
        print(f"Source: {source}")
        print(f"Published: {published_at}")
        print(f"Description: {description[:200]}...")  # truncate for preview
        print(f"Link: {url}")

if __name__ == "__main__":
    main()
# Out:
# Request URL: https://api.marketaux.com/v1/news/all?symbols=AAPL&filter_entities=true&language=en&api_token=yiVSqYtyxfk1PLFSgY7REStRB3GcnJUPLeLZFNJH
#
# === Top 3 News Articles for AAPL ===
#
# Article 1:
# Title: ASX Market Open: Dip buying Down Under won’t be enough to keep Week 9 from turning red again | Feb 25, 2025
# Source: themarketherald.com.au
# Published: 2025-02-24T21:03:28.000000Z
# Description: After barely edging into the green late yesterday, Australian shares are now…...
# Link: https://themarketonline.com.au/asx-market-open-dip-buying-down-under-wont-be-enough-to-keep-week-9-from-turning-red-again-feb-25-2025-2025-02-25/
#
# Article 2:
# Title: Inside Apple’s $500 Billion Investment
# Source: medium.com
# Published: 2025-02-24T20:48:33.000000Z
# Description: "Apple commits $500 billion to U.S. innovation, manufacturing, and AI, marking a major shift in tech investment. Discover its impact on jobs, economy, and global tech."...
# Link: https://medium.com/@vsinha027/inside-apples-500-billion-investment-0224a55f8231
#
# Article 3:
# Title: Is real estate beating technology under Trump?
# Source: medium.com
# Published: 2025-02-24T20:45:21.000000Z
# Description: Yes, Real Estate (Trump’s main industry) is beating the big technology sector (Trump’s frenemy) so far during the Second Coming of Trump. The Real Estate Select Sector SPDR Fund (XLRE) and the…...
# Link: https://medium.com/@creatix/is-real-estate-beating-technology-under-trump-dbc4d5af5350

# %% [markdown]
# # Exploring Alpha Vantage API

# %%
import requests
import os

########################################
# Alpha Vantage: Various Endpoints
########################################

def get_alpha_vantage_news(api_key, ticker, topic=None, limit=5, sort_preference="RELEVANCE"):
    """
    Fetches news articles about `ticker` from the Alpha Vantage News API.
    Defaults to sort by RELEVANCE (unless overridden with sort_preference = "LATEST" or "EARLIEST").
    Optionally filters by `topic`, applies a limit client-side.

    Returns a list of dicts with article info (title, summary, sentiment, etc.).
    """

    url = "https://www.alphavantage.co/query"

    # Base params for the NEWS_SENTIMENT endpoint
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": ticker,
        "apikey": api_key,
        # Default to RELEVANCE sorting
        "sort": sort_preference.upper()  # "RELEVANCE", "LATEST", or "EARLIEST"
    }

    if topic:
        params["topics"] = topic

    response = requests.get(url, params=params)
    print("Request URL:", response.url)  # Debugging: see the final request URL
    data = response.json()

    if "feed" not in data:
        print(f"Error fetching news from Alpha Vantage: {data}")
        return []

    articles = data["feed"]

    # Apply client-side limit
    return articles[:limit]


def get_company_overview(api_key, ticker):
    """
    Fetches the company overview (e.g., Name, Description, MarketCap, etc.)
    from Alpha Vantage using function=OVERVIEW.
    """
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "OVERVIEW",
        "symbol": ticker,
        "apikey": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()

    # If there's an error, data may contain something else
    if "Symbol" not in data:
        print(f"Error fetching company overview: {data}")
        return None

    return data


def get_etf_profile(api_key, ticker):
    """
    Fetches the ETF profile from Alpha Vantage using function=ETF_PROFILE.
    Includes data such as ETF holdings, net assets, etc. (Only works if ticker is an ETF).
    """
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "ETF_PROFILE",
        "symbol": ticker,
        "apikey": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()

    # Check for basic structure
    if "symbol" not in data:
        print(f"Error fetching ETF profile: {data}")
        return None

    return data


def get_stock_price(api_key, ticker):
    """
    Fetches the TIME_SERIES_DAILY for the given ticker and returns the most recent daily data.
    You could also return the entire time series if desired.
    """
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "TIME_SERIES_DAILY",  # or TIME_SERIES_INTRADAY
        "symbol": ticker,
        "outputsize": "compact",         # or "full"
        "apikey": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()

    if "Time Series (Daily)" not in data:
        print(f"Error fetching stock price: {data}")
        return None

    # Extract the most recent date
    time_series = data["Time Series (Daily)"]
    most_recent_date = sorted(time_series.keys(), reverse=True)[0]
    most_recent_data = time_series[most_recent_date]
    return {
        "date": most_recent_date,
        "open": most_recent_data["1. open"],
        "high": most_recent_data["2. high"],
        "low":  most_recent_data["3. low"],
        "close":most_recent_data["4. close"],
        "volume":most_recent_data["5. volume"]
    }


########################################
# Main Interactive Script
########################################
def main():
    ALPHA_VANTAGE_API_KEY = ""

    # Prompt the user for a ticker
    ticker = input("Enter the company ticker symbol (e.g., AAPL, TSLA, SPY for ETF): ").upper()

    # Prompt user for the data type they want
    print("\nWhat type of data do you want?")
    print("1) News")
    print("2) Company Overview")
    print("3) ETF Profile")
    print("4) Stock Price (Daily)")
    choice = input("Enter 1/2/3/4: ").strip()

    if choice == "1":
        # NEWS
        limit_str = input("How many news articles would you like? (default 5): ")
        try:
            limit = int(limit_str)
        except ValueError:
            limit = 5

        # Prompt for optional topic
        print("\nAvailable topics include: blockchain, earnings, ipo, finance, technology, etc.")
        topic_input = input("Enter a topic from the list above (or leave blank for none): ").strip()

        # Prompt for sort preference; default to RELEVANCE if blank or invalid
        print("\nSort options: RELEVANCE, LATEST, EARLIEST")
        sort_input = input("How would you like to sort the news? (default RELEVANCE): ").strip().upper()
        valid_sorts = ["RELEVANCE", "LATEST", "EARLIEST"]
        if sort_input not in valid_sorts:
            sort_input = "RELEVANCE"

        articles = get_alpha_vantage_news(
            api_key=ALPHA_VANTAGE_API_KEY,
            ticker=ticker,
            topic=topic_input if topic_input else None,
            limit=limit,
            sort_preference=sort_input
        )

        if not articles:
            print("No articles found or there was an error.")
            return

        print(f"\n=== Top {limit} {sort_input.title()} News Articles for {ticker} ===")
        for i, article in enumerate(articles, start=1):
            title = article.get("title", "No Title")
            summary = article.get("summary", "No Summary")
            sentiment = article.get("overall_sentiment_label", "No Sentiment")
            url = article.get("url", "No URL")

            print(f"\nArticle {i}:")
            print(f"Title: {title}")
            print(f"Sentiment: {sentiment}")
            print(f"Summary: {summary[:200]}...")
            print(f"Link: {url}")

    elif choice == "2":
        # COMPANY OVERVIEW
        overview_data = get_company_overview(ALPHA_VANTAGE_API_KEY, ticker)
        if not overview_data:
            return
        print(f"\n=== Company Overview for {ticker} ===")
        for key, val in overview_data.items():
            print(f"{key}: {val}")

    elif choice == "3":
        # ETF PROFILE
        etf_data = get_etf_profile(ALPHA_VANTAGE_API_KEY, ticker)
        if not etf_data:
            return
        print(f"\n=== ETF Profile for {ticker} ===")
        for key, val in etf_data.items():
            print(f"{key}: {val}")

    elif choice == "4":
        # STOCK PRICE (TIME_SERIES_DAILY)
        stock_data = get_stock_price(ALPHA_VANTAGE_API_KEY, ticker)
        if not stock_data:
            return
        print(f"\n=== Latest Stock Price for {ticker} ===")
        print(f"Date:  {stock_data['date']}")
        print(f"Open:  {stock_data['open']}")
        print(f"High:  {stock_data['high']}")
        print(f"Low:   {stock_data['low']}")
        print(f"Close: {stock_data['close']}")
        print(f"Volume:{stock_data['volume']}")

    else:
        print("Invalid choice. Exiting.")


if __name__ == "__main__":
    main()
# Out:
# What type of data do you want?
# 1) News
# 2) Company Overview
# 3) ETF Profile
# 4) Stock Price (Daily)
#
# Available topics include: blockchain, earnings, ipo, finance, technology, etc.
#
# Sort options: RELEVANCE, LATEST, EARLIEST
# Request URL: https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=RAL8AFRU7F2Y9ZPI&sort=RELEVANCE
#
# === Top 5 Relevance News Articles for AAPL ===
#
# Article 1:
# Title: This Solar Company's 5-Year Return Makes Bitcoin, Dogecoin, Tesla, Disney, Apple, Microsoft, Ford And Amazon Look Trivial
# Sentiment: Neutral
# Summary: Enphase Energy Inc ( NASDAQ: ENPH ) is known as a global leader in solar energy solutions, and over the past five years, delivered beaming returns for traders and investors. Since May 2017, Enphase En...
# Link: https://www.benzinga.com/markets/cryptocurrency/22/05/27337504/this-solar-companys-5-year-return-makes-bitcoin-dogecoin-tesla-disney-apple-microsoft-ford
#
# Article 2:
# Title: US Warns China Against Helping Russia In Ukraine War
# Sentiment: Neutral
# Summary: Russia sought China's military equipment to support its invasion of Ukraine, Financial Times reports citing U.S. officials.
# The U.S. looks to caution its allies against China's possible assistance to...
# Link: https://www.benzinga.com/government/22/03/26119946/us-warns-china-against-helping-russia-in-ukraine-war
#
# Article 3:
# Title: This Oil Company Has A Better 1-Year Return Than Tesla, Lucid, Apple, Microsoft, Bitcoin And Ethereum
# Sentiment: Neutral
# Summary: Occidental Petroleum Corporation OXY is a global leader in hydrocarbon exploration, and over the past year, treated investors to eye-popping returns....
# Link: https://www.benzinga.com/markets/cryptocurrency/22/03/26211164/this-oil-company-has-a-better-1-year-return-than-tesla-lucid-bitcoin-ethereum-and-apple
#
# Article 4:
# Title: This Clean Energy Company Has A Better 5-Year Return Than Starbucks, Ford, Microsoft, Apple, Disney, Netflix And Amazon
# Sentiment: Somewhat-Bullish
# Summary: Since 1997, Plug Power Inc PLUG has helped businesses optimize their carbon footprints, and over the past 5 years, produced eye-popping returns for investors....
# Link: https://www.benzinga.com/markets/cryptocurrency/22/03/26112072/this-clean-energy-company-has-a-better-5-year-return-than-sbux-ford-microsoft-apple-disne
#
# Article 5:
# Title: This Bitcoin-Related Company Has A Better 2-Year Return Than Tesla, Ford, Microsoft, Apple, Disney, Netflix And Amazon
# Sentiment: Neutral
# Summary: Riot Blockchain Inc  ( NASDAQ: RIOT )  is a leader in North American Bitcoin  ( CRYPTO: BTC )  mining activities, and over the past 2 years, has produced eye-popping returns for investors.
# Since April...
# Link: https://www.benzinga.com/markets/cryptocurrency/22/04/26437195/this-bitcoin-related-company-has-a-better-2-year-return-than-tesla-ford-microsoft-apple-di

# %% [markdown]
# # API workflow

# %%
import requests
import json
import pandas as pd

def get_alpha_vantage_news(api_key, ticker, sort_preference="RELEVANCE"):
    """
    Fetches news articles about `ticker` from Alpha Vantage's NEWS_SENTIMENT endpoint.
    Returns a JSON string.
    """
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": ticker,
        "apikey": api_key,
        "sort": sort_preference.upper()  # RELEVANCE, LATEST, EARLIEST
    }

    response = requests.get(url, params=params)
    data = response.json()

    if "feed" not in data:
        print(f"Error fetching news from Alpha Vantage: {data}")
        return None

    return json.dumps(data, indent=4)  # Convert JSON to a readable string


def get_company_overview(api_key, ticker):
    """
    Fetches the company overview from Alpha Vantage using function=OVERVIEW.
    Returns a Pandas DataFrame.
    """
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "OVERVIEW",
        "symbol": ticker,
        "apikey": api_key
    }

    response = requests.get(url, params=params)
    data = response.json()

    if "Symbol" not in data:
        print(f"Error fetching company overview: {data}")
        return None

    # Convert JSON dictionary to a Pandas DataFrame
    overview_df = pd.DataFrame.from_dict(data, orient='index', columns=['Value'])
    overview_df.reset_index(inplace=True)
    overview_df.columns = ['Field', 'Value']

    return overview_df


def main():
    ALPHA_VANTAGE_API_KEY = "YOUR_ALPHA_VANTAGE_API_KEY"

    # Prompt user for a ticker symbol
    ticker = input("Enter the company ticker symbol (e.g., AAPL, TSLA): ").upper()

    print("\nFetching company overview and news articles...\n")

    # Fetch data
    company_overview_df = get_company_overview(ALPHA_VANTAGE_API_KEY, ticker)
    news_json = get_alpha_vantage_news(ALPHA_VANTAGE_API_KEY, ticker)

    if company_overview_df is None and not news_json:
        print("No data found or there was an error.")
        return

    # Print the Company Overview DataFrame
    if company_overview_df is not None:
        print("\n=== Company Overview ===")
        print(company_overview_df)

    # Print the News Articles JSON
    if news_json:
        print("\n=== News Articles ===\n")
        print(news_json)

    return company_overview_df, news_json


if __name__ == "__main__":
    company_overview_df, final_news_text = main()
# Out:
# Fetching company overview and news articles...
#
#
# === Company Overview ===
#                          Field  \
# 0                       Symbol
# 1                    AssetType
# 2                         Name
# 3                  Description
# 4                          CIK
# 5                     Exchange
# 6                     Currency
# 7                      Country
# 8                       Sector
# 9                     Industry
# 10                     Address
# 11                OfficialSite
# 12               FiscalYearEnd
# 13               LatestQuarter
# 14        MarketCapitalization
# 15                      EBITDA
# 16                     PERatio
# 17                    PEGRatio
# 18                   BookValue
# 19            DividendPerShare
# 20               DividendYield
# 21                         EPS
# 22          RevenuePerShareTTM
# 23                ProfitMargin
# 24          OperatingMarginTTM
# 25           ReturnOnAssetsTTM
# 26           ReturnOnEquityTTM
# 27                  RevenueTTM
# 28              GrossProfitTTM
# 29               DilutedEPSTTM
# 30  QuarterlyEarningsGrowthYOY
# 31   QuarterlyRevenueGrowthYOY
# 32          AnalystTargetPrice
# 33      AnalystRatingStrongBuy
# 34            AnalystRatingBuy
# 35           AnalystRatingHold
# 36           AnalystRatingSell
# 37     AnalystRatingStrongSell
# 38                  TrailingPE
# 39                   ForwardPE
# 40        PriceToSalesRatioTTM
# 41            PriceToBookRatio
# 42                 EVToRevenue
# 43                  EVToEBITDA
# 44                        Beta
# 45                  52WeekHigh
# 46                   52WeekLow
# 47          50DayMovingAverage
# 48         200DayMovingAverage
# 49           SharesOutstanding
# 50                DividendDate
# 51              ExDividendDate
#
#                                                 Value
# 0                                                AAPL
# 1                                        Common Stock
# 2                                           Apple Inc
# 3   Apple Inc. is an American multinational techno...
# 4                                              320193
# 5                                              NASDAQ
# 6                                                 USD
# 7                                                 USA
# 8                                          TECHNOLOGY
# 9                                ELECTRONIC COMPUTERS
# 10               ONE INFINITE LOOP, CUPERTINO, CA, US
# 11                              https://www.apple.com
# 12                                          September
# 13                                         2024-12-31
# 14                                      3632944644000
# 15                                       137352004000
# 16                                              38.45
# 17                                              2.198
# 18                                              4.438
# 19                                               0.99
# 20                                             0.0042
# 21                                               6.29
# 22                                              25.97
# 23                                              0.243
# 24                                              0.345
# 25                                              0.225
# 26                                              1.365
# 27                                       395760009000
# 28                                       184102994000
# 29                                               6.29
# 30                                              0.101
# 31                                               0.04
# 32                                             252.23
# 33                                                  8
# 34                                                 21
# 35                                                 13
# 36                                                  2
# 37                                                  2
# 38                                              38.45
# 39                                              32.26
# 40                                               9.18
# 41                                               53.4
# 42                                               9.12
# 43                                              26.27
# 44                                                1.2
# 45                                             259.81
# 46                                             163.31
# 47                                             240.35
# 48                                             225.59
# 49                                        15022100000
# 50                                         2025-02-13
# 51                                         2025-02-10
#
# === News Articles ===
#
# {
#     "items": "50",
#     "sentiment_score_definition": "x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish",
#     "relevance_score_definition": "0 < x <= 1, with a higher score indicating higher relevance.",
#     "feed": [
#         {
#             "title": "This Solar Company's 5-Year Return Makes Bitcoin, Dogecoin, Tesla, Disney, Apple, Microsoft, Ford And Amazon Look Trivial",
#             "url": "https://www.benzinga.com/markets/cryptocurrency/22/05/27337504/this-solar-companys-5-year-return-makes-bitcoin-dogecoin-tesla-disney-apple-microsoft-ford",
#             "time_published": "20220521T175105",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Enphase Energy Inc ( NASDAQ: ENPH ) is known as a global leader in solar energy solutions, and over the past five years, delivered beaming returns for traders and investors. Since May 2017, Enphase Energy stock's 5-year return has outperformed several of the world's most popular cryptocurrencies,",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2022/05/21/man-2425121.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Trading",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Blockchain",
#                     "relevance_score": "0.158519"
#                 }
#             ],
#             "overall_sentiment_score": 0.114801,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.977196",
#                     "ticker_sentiment_score": "0.044254",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ENPH",
#                     "relevance_score": "0.706644",
#                     "ticker_sentiment_score": "0.172183",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "1.0",
#                     "ticker_sentiment_score": "0.044459",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.977196",
#                     "ticker_sentiment_score": "0.044301",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "F",
#                     "relevance_score": "0.706644",
#                     "ticker_sentiment_score": "0.047617",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.516401",
#                     "ticker_sentiment_score": "0.043455",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "DIS",
#                     "relevance_score": "0.999765",
#                     "ticker_sentiment_score": "0.047617",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:BTC",
#                     "relevance_score": "0.400691",
#                     "ticker_sentiment_score": "0.044611",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:DOGE",
#                     "relevance_score": "0.400691",
#                     "ticker_sentiment_score": "0.044284",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "US Warns China Against Helping Russia In Ukraine War",
#             "url": "https://www.benzinga.com/government/22/03/26119946/us-warns-china-against-helping-russia-in-ukraine-war",
#             "time_published": "20220314T122305",
#             "authors": [],
#             "summary": "Russia sought China's military equipment to support its invasion of Ukraine, Financial Times reports citing U.S. officials. \nThe U.S. looks to caution its allies against China's possible assistance to Russia. \nRussia could also have fallen short of weaponry as the war extended into its third week.\nB",
#             "banner_image": "https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/us_china_7.png",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.057713,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.926285",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "NFLX",
#                     "relevance_score": "1.0",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.999652",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "1.0",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "FB",
#                     "relevance_score": "0.497551",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TWTR",
#                     "relevance_score": "1.0",
#                     "ticker_sentiment_score": "-0.001084",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "This Oil Company Has A Better 1-Year Return Than Tesla, Lucid, Apple, Microsoft, Bitcoin And Ethereum",
#             "url": "https://www.benzinga.com/markets/cryptocurrency/22/03/26211164/this-oil-company-has-a-better-1-year-return-than-tesla-lucid-bitcoin-ethereum-and-apple",
#             "time_published": "20220628T132300",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Occidental Petroleum Corporation OXY is a global leader in hydrocarbon exploration, and over the past year, treated investors to eye-popping returns.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2012/stock-624712_2.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Markets",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.158519"
#                 },
#                 {
#                     "topic": "Real Estate & Construction",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.25"
#                 },
#                 {
#                     "topic": "Blockchain",
#                     "relevance_score": "0.158519"
#                 }
#             ],
#             "overall_sentiment_score": 0.016777,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "1.0",
#                     "ticker_sentiment_score": "0.093656",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "LCID",
#                     "relevance_score": "0.99687",
#                     "ticker_sentiment_score": "0.093049",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "OXY",
#                     "relevance_score": "0.445439",
#                     "ticker_sentiment_score": "0.042515",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999999",
#                     "ticker_sentiment_score": "0.094167",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.569256",
#                     "ticker_sentiment_score": "0.094312",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:BTC",
#                     "relevance_score": "0.99687",
#                     "ticker_sentiment_score": "0.093724",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:ETH",
#                     "relevance_score": "0.969748",
#                     "ticker_sentiment_score": "0.094252",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:DOGE",
#                     "relevance_score": "0.306389",
#                     "ticker_sentiment_score": "0.10273",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "This Clean Energy Company Has A Better 5-Year Return Than Starbucks, Ford, Microsoft, Apple, Disney, Netflix And Amazon",
#             "url": "https://www.benzinga.com/markets/cryptocurrency/22/03/26112072/this-clean-energy-company-has-a-better-5-year-return-than-sbux-ford-microsoft-apple-disne",
#             "time_published": "20220629T170300",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Since 1997, Plug Power Inc PLUG has helped businesses optimize their carbon footprints, and over the past 5 years, produced eye-popping returns for investors.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2012/ships-6073537_0.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Trading",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.333333"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.333333"
#                 }
#             ],
#             "overall_sentiment_score": 0.193517,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.99835",
#                     "ticker_sentiment_score": "0.0474",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "NFLX",
#                     "relevance_score": "0.778963",
#                     "ticker_sentiment_score": "0.047527",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999995",
#                     "ticker_sentiment_score": "0.047684",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SBUX",
#                     "relevance_score": "0.400052",
#                     "ticker_sentiment_score": "0.04751",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "F",
#                     "relevance_score": "0.515636",
#                     "ticker_sentiment_score": "0.05124",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PLUG",
#                     "relevance_score": "0.61795",
#                     "ticker_sentiment_score": "0.275036",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.400052",
#                     "ticker_sentiment_score": "0.04724",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "DIS",
#                     "relevance_score": "0.985617",
#                     "ticker_sentiment_score": "0.05124",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "This Bitcoin-Related Company Has A Better 2-Year Return Than Tesla, Ford, Microsoft, Apple, Disney, Netflix And Amazon",
#             "url": "https://www.benzinga.com/markets/cryptocurrency/22/04/26437195/this-bitcoin-related-company-has-a-better-2-year-return-than-tesla-ford-microsoft-apple-di",
#             "time_published": "20220402T172039",
#             "authors": [
#                 "Henry Khederian"
#             ],
#             "summary": "Riot Blockchain Inc  ( NASDAQ: RIOT )  is a leader in North American Bitcoin  ( CRYPTO: BTC )  mining activities, and over the past 2 years, has produced eye-popping returns for investors.\nSince April 2020, Riot Blockchain stock's 2-year return has outperformed several of the world's most popular te",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2012/cryptocurrency-3435863.jpg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "Trading",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Life Sciences",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.2"
#                 },
#                 {
#                     "topic": "Blockchain",
#                     "relevance_score": "0.769861"
#                 }
#             ],
#             "overall_sentiment_score": 0.006834,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.996397",
#                     "ticker_sentiment_score": "0.032044",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "NFLX",
#                     "relevance_score": "0.769328",
#                     "ticker_sentiment_score": "0.03188",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999981",
#                     "ticker_sentiment_score": "0.032289",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.506613",
#                     "ticker_sentiment_score": "0.0313",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "HYMC",
#                     "relevance_score": "0.135959",
#                     "ticker_sentiment_score": "0.029324",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "F",
#                     "relevance_score": "0.506613",
#                     "ticker_sentiment_score": "0.034422",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "RIOT",
#                     "relevance_score": "0.695767",
#                     "ticker_sentiment_score": "0.035644",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.506613",
#                     "ticker_sentiment_score": "0.032032",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "DIS",
#                     "relevance_score": "0.983482",
#                     "ticker_sentiment_score": "0.034422",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CRYPTO:BTC",
#                     "relevance_score": "0.392537",
#                     "ticker_sentiment_score": "0.041119",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Raises Prices for Streaming Music and Video",
#             "url": "https://www.barrons.com/articles/apple-raises-prices-streaming-music-video-51666633156",
#             "time_published": "20221024T174000",
#             "authors": [
#                 "Eric J. Savitz"
#             ],
#             "summary": "Apple has raised subscription prices for its streaming music and video services, effective Monday. The company ( ticker: AAPL ) lifted the price of Apple TV+ to $6.99 a month, from $4.99. For Apple Music, an individual subscription goes up a dollar a month to $10.99, while the family plan is now ...",
#             "banner_image": "https://images.barrons.com/im-397582/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.126574,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999965",
#                     "ticker_sentiment_score": "0.230389",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Unveils New Products Ahead of the Holidays. The Company Is Flexing Its Muscles, Analyst Says.",
#             "url": "https://www.barrons.com/articles/apple-ipad-pro-tv-51666118305",
#             "time_published": "20221018T184000",
#             "authors": [
#                 "Angela Palumbo"
#             ],
#             "summary": "Apple Unveils New iPad Pro and Apple TV ...",
#             "banner_image": "https://images.barrons.com/im-646229/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "0.310843"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.320165,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999957",
#                     "ticker_sentiment_score": "0.5433",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Reportedly Mulls Subscription Plans for Hardware. Finally.",
#             "url": "https://www.barrons.com/articles/apple-stock-subscription-plans-hardware-51648156752",
#             "time_published": "20220324T212206",
#             "authors": [
#                 "Eric J. Savitz"
#             ],
#             "summary": "For years now, Wall Street has speculated that Apple someday could adopt a subscription model for iPhones and other hardware devices: iPhone-as-a-service.",
#             "banner_image": "https://images.barrons.com/im-511749/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.304886,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999861",
#                     "ticker_sentiment_score": "-0.304886",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple suffers widespread outage, services down for some users",
#             "url": "https://www.marketwatch.com/story/apple-suffers-widespread-outage-services-down-for-some-users-11647889503",
#             "time_published": "20220321T180500",
#             "authors": [
#                 "Talal Ansari"
#             ],
#             "summary": "Apple Inc. said several of its properties were suffering from an outage Monday, disrupting access for users and businesses.",
#             "banner_image": "https://images.mktw.net/im-475991/social",
#             "source": "MarketWatch",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.marketwatch.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.184153,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999836",
#                     "ticker_sentiment_score": "-0.184153",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Watch Series 3 Is Nearing The End Of Its Life, Analyst Says - Here's Why",
#             "url": "https://www.benzinga.com/analyst-ratings/analyst-color/22/03/26232508/apple-watch-series-3-is-nearing-the-end-of-its-life-analyst-says-heres-why",
#             "time_published": "20220322T112443",
#             "authors": [],
#             "summary": "Apple Inc.  ( NASDAQ: AAPL )  may discontinue Its Watch Series 3 in the third quarter of this year, according to prominent analyst Ming-Chi Kuo.\nWhat Happened: The Apple Watch 3 may reach the end of its life in the third quarter since its computing power will not meet the requirements of the new ver",
#             "banner_image": "https://cdn.benzinga.com/files/imagecache/story_image_685x375C/images/story/2012/watch_series_3.jpeg",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.108179"
#                 }
#             ],
#             "overall_sentiment_score": -0.036693,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999579",
#                     "ticker_sentiment_score": "-0.019923",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Reports Outages for App Store, Music, Some Other Services",
#             "url": "https://www.barrons.com/articles/apple-reports-outages-51647889644",
#             "time_published": "20220321T200800",
#             "authors": [
#                 "Eric J. Savitz"
#             ],
#             "summary": "Apple is seeing outages Monday for some services, according to its system status page.",
#             "banner_image": "https://images.barrons.com/im-508969/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.380106,
#             "overall_sentiment_label": "Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999495",
#                     "ticker_sentiment_score": "-0.380106",
#                     "ticker_sentiment_label": "Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Reports Outages for App Store, Music, Some Other Services",
#             "url": "https://www.barrons.com/articles/apple-outages-51647889644",
#             "time_published": "20220321T200800",
#             "authors": [
#                 "Eric J. Savitz"
#             ],
#             "summary": "Apple is seeing outages Monday for some services, according to its system status page.",
#             "banner_image": "https://images.barrons.com/im-508969/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.380106,
#             "overall_sentiment_label": "Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999495",
#                     "ticker_sentiment_score": "-0.380106",
#                     "ticker_sentiment_label": "Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "New Apple Card Users Can Get Up To 10% Daily Cash Back For A Limited Time - Apple  ( NASDAQ:AAPL ) ",
#             "url": "https://www.benzinga.com/news/23/07/33199065/new-apple-card-users-can-get-up-to-10-daily-cash-back-for-a-limited-time",
#             "time_published": "20230712T134918",
#             "authors": [
#                 "Rounak Jain"
#             ],
#             "summary": "Apple Inc. AAPL has launched a promotion for new Apple Card customers, boosting the Daily Cash back offer on purchases made using the credit to 10%, from the usual range of 1% to 3%.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2023/Apple_Card_0.jpeg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.170592,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999476",
#                     "ticker_sentiment_score": "0.32616",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple terminates Epic Games' developer account in latest clash between the two companies",
#             "url": "https://www.marketwatch.com/story/apple-terminates-epic-games-developer-account-in-latest-clash-between-the-two-companies-22b8bc15",
#             "time_published": "20240306T175800",
#             "authors": [
#                 "Jon Swartz"
#             ],
#             "summary": "In the latest conflagration between Apple Inc. and Epic Games Inc., Apple has terminated Epic's application for a developer account to launch an app store for iPhones in Europe.",
#             "banner_image": "https://images.mktw.net/im-77780461/social",
#             "source": "MarketWatch",
#             "category_within_source": "Top Stories",
#             "source_domain": "www.marketwatch.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.035087,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999463",
#                     "ticker_sentiment_score": "0.064318",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple's iPhone Event Will Be a Key Moment for the Stock",
#             "url": "https://www.barrons.com/articles/apple-iphone-event-stock-price-today-51662500747",
#             "time_published": "20220906T215500",
#             "authors": [
#                 "Connor Smith"
#             ],
#             "summary": "Apple's iPhone Event Is Wednesday. What to Watch. ...",
#             "banner_image": "https://images.barrons.com/im-617619?width=620&height=413",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.014151,
#             "overall_sentiment_label": "Neutral",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999463",
#                     "ticker_sentiment_score": "-0.025877",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Is Down 5% in May. The S&P 500 Is Flat. Mind the Gap.",
#             "url": "https://www.barrons.com/articles/apple-stock-price-market-may-51653997656",
#             "time_published": "20220531T154500",
#             "authors": [
#                 "Sabrina Escobar"
#             ],
#             "summary": "Apple Stock Has Had a Dreadful May. The Stock Market Has Held Up. Barron's",
#             "banner_image": "https://images.barrons.com/im-533381/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.161647"
#                 }
#             ],
#             "overall_sentiment_score": -0.163749,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999276",
#                     "ticker_sentiment_score": "-0.163749",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Is Down 5% in May. The S&P 500 Is Flat. Mind the Gap.",
#             "url": "https://www.barrons.com/articles/apple-stock-price-market-may-51653997656",
#             "time_published": "20220531T135100",
#             "authors": [
#                 "Sabrina Escobar"
#             ],
#             "summary": "Apple Stock Has Had a Dreadful May. The Stock Market Has Held Up. Barron's",
#             "banner_image": "https://images.barrons.com/im-533381/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.161647"
#                 }
#             ],
#             "overall_sentiment_score": -0.163749,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999276",
#                     "ticker_sentiment_score": "-0.163749",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "New And Returning Apple Card Users Score Exclusive Subscription Deals Until Jan. 31 - Sony Group  ( NYSE:SONY ) ",
#             "url": "https://www.benzinga.com/general/entertainment/24/01/36693426/new-and-returning-apple-card-users-score-exclusive-subscription-deals-until-jan-31",
#             "time_published": "20240119T123656",
#             "authors": [
#                 "Rounak Jain"
#             ],
#             "summary": "Apple Inc. AAPL has unveiled a new set of perks for Apple Card users. The tech giant is offering up to three months of free subscription to most of its online services. What Happened: The Apple Card offer encompasses services such as Apple TV+, Apple Music, Apple Arcade, Apple Fitness+, and Apple ...",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2024/Apple-Card.jpeg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "General",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.302725,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "SNEJF",
#                     "relevance_score": "0.42503",
#                     "ticker_sentiment_score": "0.489744",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999233",
#                     "ticker_sentiment_score": "0.548449",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple to Offer High-Yield Savings Account From Goldman to Card Holders",
#             "url": "https://www.barrons.com/articles/apple-high-yield-savings-account-goldman-sachs-51665676575",
#             "time_published": "20221013T155600",
#             "authors": [
#                 "Angela Palumbo"
#             ],
#             "summary": "Apple continues to branch into consumer finance as it announces a new high-yield savings account with Goldman Sachs for Apple Card holders. Apple ( ticker: AAPL ) announced a new high-yield savings account on Thursday that will be available in the coming months.",
#             "banner_image": "https://images.barrons.com/im-643558/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.5"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "0.108179"
#                 }
#             ],
#             "overall_sentiment_score": 0.38899,
#             "overall_sentiment_label": "Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "GS",
#                     "relevance_score": "0.9545",
#                     "ticker_sentiment_score": "0.6302",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999142",
#                     "ticker_sentiment_score": "0.636117",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple's iPhone 14 Price Isn't Rising for U.S. Consumers. Why This Matters.",
#             "url": "https://www.barrons.com/articles/apples-iphone-14-price-51663008434",
#             "time_published": "20220912T184800",
#             "authors": [
#                 "Angela Palumbo"
#             ],
#             "summary": "Apple's new iPhone and its price has excited many buyers and analysts, and this looks like good news for the tech giant. Apple ( ticker: AAPL ) announced a slew of new products at its \"Far Out\" event last week, including the Apple Watch Series 8, the Apple Watch Ultra and , of course, the iPhone ...",
#             "banner_image": "https://images.barrons.com/im-621084/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.197051,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999142",
#                     "ticker_sentiment_score": "0.0",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         },
#         {
#             "title": "Sony Has A Black Friday Treat For PlayStation 5 Owners: Six Months Of Free Apple Music, Here's How To Get It - Sony Group  ( NYSE:SONY ) ",
#             "url": "https://www.benzinga.com/general/gaming/23/11/35822415/sony-has-a-black-friday-treat-for-playstation-5-owners-six-months-of-free-apple-music-heres-how-to",
#             "time_published": "20231116T104454",
#             "authors": [
#                 "Rounak Jain"
#             ],
#             "summary": "Sony Group Corp. SONY has a sweet new Black Friday deal for existing PlayStation 5 owners, offering a free six-month subscription to Apple Music. What Happened: If you already have a PlayStation 5 gaming console, you can grab a six-month of Apple Music subscription for free.",
#             "banner_image": "https://cdn.benzinga.com/files/images/story/2023/Playstation-5.jpeg?width=1200&height=800&fit=crop",
#             "source": "Benzinga",
#             "category_within_source": "News",
#             "source_domain": "www.benzinga.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": 0.421127,
#             "overall_sentiment_label": "Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "SNEJF",
#                     "relevance_score": "0.441059",
#                     "ticker_sentiment_score": "0.547413",
#                     "ticker_sentiment_label": "Bullish"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.999073",
#                     "ticker_sentiment_score": "0.716043",
#                     "ticker_sentiment_label": "Bullish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple Launches 'Pay Later' Service. Affirm Shares Swoon.",
#             "url": "https://www.barrons.com/articles/apple-pay-later-announcement-affirm-ba34d51b",
#             "time_published": "20230328T173100",
#             "authors": [
#                 "Eric J. Savitz"
#             ],
#             "summary": "Apple on Tuesday announced the launch of Apple Pay Later, the company's long-anticipated entry into the \"buy now, pay later\" space. The new service will allow consumers to split purchases made via Apple Pay through the Apple Wallet app on iPhones and iPads into four payments, spread over six ...",
#             "banner_image": "https://images.barrons.com/im-752598/social",
#             "source": "Barrons",
#             "category_within_source": "n/a",
#             "source_domain": "www.barrons.com",
#             "topics": [
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "1.0"
#                 }
#             ],
#             "overall_sentiment_score": -0.18177,
#             "overall_sentiment_label": "Somewhat-Bearish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.998935",
#                     "ticker_sentiment_score": "-0.322468",
#                     "ticker_sentiment_label": "Somewhat-Bearish"
#                 }
#             ]
#         },
#         {
#             "title": "Apple's march toward a $3 trillion valuation, shown in one chart",
#             "url": "https://www.marketwatch.com/story/apples-march-toward-a-3-trillion-valuation-shown-in-one-chart-94f24a6d",
#             "time_published": "20230628T191300",
# ...
#             ]
#         },
#         {
#             "title": "Weekly Roundup",
#             "url": "https://aap.thestreet.com/story/16129862/1/weekly-roundup.html",
#             "time_published": "20230728T225600",
#             "authors": [],
#             "summary": "We had a jam-packed week filled with earnings both in and out of the Action Alerts PLUS portfolio, as well as the latest Fed policy meeting that, as expected, saw the central bank lift the Fed Funds rate another quarter-percentage point.",
#             "banner_image": "https://s.thestreet.com/files/tsc/v2008/photos/contrib/uploads/d9441055-2d89-11ee-9f06-9fa6dbfb6f3e.png",
#             "source": "The Street",
#             "category_within_source": "GoogleRSS",
#             "source_domain": "aap.thestreet.com",
#             "topics": [
#                 {
#                     "topic": "Life Sciences",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Energy & Transportation",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Technology",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Finance",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Economy - Monetary",
#                     "relevance_score": "0.990678"
#                 },
#                 {
#                     "topic": "Retail & Wholesale",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Financial Markets",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Manufacturing",
#                     "relevance_score": "0.142857"
#                 },
#                 {
#                     "topic": "Earnings",
#                     "relevance_score": "1.0"
#                 },
#                 {
#                     "topic": "Real Estate & Construction",
#                     "relevance_score": "0.142857"
#                 }
#             ],
#             "overall_sentiment_score": 0.202254,
#             "overall_sentiment_label": "Somewhat-Bullish",
#             "ticker_sentiment": [
#                 {
#                     "ticker": "DE",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.124589",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AAPL",
#                     "relevance_score": "0.009998",
#                     "ticker_sentiment_score": "0.115201",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MDNDF",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.082645",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TRIN",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.091309",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TEX",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.071524",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "STT",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "-0.019139",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "TSLA",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.017466",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MA",
#                     "relevance_score": "0.013331",
#                     "ticker_sentiment_score": "0.132319",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SBUX",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.095718",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BLNK",
#                     "relevance_score": "0.013331",
#                     "ticker_sentiment_score": "0.117489",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "IRBT",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.070575",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "OLED",
#                     "relevance_score": "0.036648",
#                     "ticker_sentiment_score": "0.075013",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CMG",
#                     "relevance_score": "0.023327",
#                     "ticker_sentiment_score": "0.03273",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "HTLD",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.069454",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MS",
#                     "relevance_score": "0.009998",
#                     "ticker_sentiment_score": "0.104302",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "RDWR",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.060189",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "FTNT",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.060189",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CHPT",
#                     "relevance_score": "0.039977",
#                     "ticker_sentiment_score": "0.117378",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CAT",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.071524",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CNA",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.069454",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "XOM",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.07836",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "IPAR",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.063289",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "QRVO",
#                     "relevance_score": "0.013331",
#                     "ticker_sentiment_score": "0.080132",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMAT",
#                     "relevance_score": "0.026658",
#                     "ticker_sentiment_score": "0.086903",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CVS",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "-0.017107",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "C",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.116854",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CVX",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.07836",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "F",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.050112",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "JPM",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.114316",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AXON",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.103488",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "URI",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.078309",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MSFT",
#                     "relevance_score": "0.026658",
#                     "ticker_sentiment_score": "0.092232",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SSNLF",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.056982",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "COST",
#                     "relevance_score": "0.019995",
#                     "ticker_sentiment_score": "0.15856",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "AWK",
#                     "relevance_score": "0.009998",
#                     "ticker_sentiment_score": "0.130063",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "QCOM",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.083993",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "WFC",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.130834",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "LRCX",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.039976",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "SPGI",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.007768",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ON",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.067323",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GOOG",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.093968",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "HUM",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "-0.017107",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "MSI",
#                     "relevance_score": "0.009998",
#                     "ticker_sentiment_score": "0.10249",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "BAC",
#                     "relevance_score": "0.026658",
#                     "ticker_sentiment_score": "0.124213",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GM",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.081454",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "USEG",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.039154",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "CBOE",
#                     "relevance_score": "0.013331",
#                     "ticker_sentiment_score": "0.105018",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "GS",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.091988",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "ICNB",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.177608",
#                     "ticker_sentiment_label": "Somewhat-Bullish"
#                 },
#                 {
#                     "ticker": "VMC",
#                     "relevance_score": "0.016663",
#                     "ticker_sentiment_score": "0.080783",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "LMT",
#                     "relevance_score": "0.009998",
#                     "ticker_sentiment_score": "0.106491",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "INTC",
#                     "relevance_score": "0.019995",
#                     "ticker_sentiment_score": "0.077132",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AXP",
#                     "relevance_score": "0.003333",
#                     "ticker_sentiment_score": "0.130834",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "EVGO",
#                     "relevance_score": "0.013331",
#                     "ticker_sentiment_score": "0.117489",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "PEP",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.0635",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "AMZN",
#                     "relevance_score": "0.033319",
#                     "ticker_sentiment_score": "0.09288",
#                     "ticker_sentiment_label": "Neutral"
#                 },
#                 {
#                     "ticker": "FOREX:USD",
#                     "relevance_score": "0.006666",
#                     "ticker_sentiment_score": "0.085203",
#                     "ticker_sentiment_label": "Neutral"
#                 }
#             ]
#         }
#     ]
# }
